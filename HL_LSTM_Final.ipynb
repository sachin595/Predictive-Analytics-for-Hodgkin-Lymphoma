# %%
import pandas as pd
import numpy as np
import joblib
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
# Load the dataset
data = pd.read_csv("C:/Users/sachi/Downloads/Johns_Hopkins/ONCO_datasets/LL CDC data sets/Lymphoma/HL DATA_1.csv")

# %%
# Define the mappings
sex_mapping = {'Male': 0, 'Female': 1}
ethnicity_mapping = {'Hispanic': 1, 'Non-Hispanic': 0}
race_mapping = {'White': 1, 'Black or African American': 0, 'Asian or Pacific Islander': 2}

# %%
# Replace the values using the mappings
data['Sex'] = data['Sex'].replace(sex_mapping)
data['Ethnicity'] = data['Ethnicity'].replace(ethnicity_mapping)
data['Race'] = data['Race'].replace(race_mapping)

# Define the mapping function for AgeGroup
def map_age_group(age_group):
    if age_group == '1-4 years':
        return 0
    elif age_group == '5-9 years':
        return 1
    elif age_group == '10-14 years':
        return 2
    elif age_group == '15-19 years':
        return 3
    elif age_group == '20-24 years':
        return 4
    elif age_group == '25-29 years':
        return 5
    elif age_group == '30-34 years':
        return 6
    elif age_group == '35-39 years':
        return 7
    elif age_group == '40-44 years':
        return 8
    elif age_group == '45-49 years':
        return 9
    elif age_group == '50-54 years':
        return 10
    elif age_group == '55-59 years':
        return 11
    elif age_group == '60-64 years':
        return 12
    elif age_group == '65-69 years':
        return 13
    elif age_group == '70-74 years':
        return 14
    elif age_group == '75-79 years':
        return 15
    elif age_group == '80-84 years':
        return 16
    elif age_group == '85+ years':
        return 17
    else:
        return 18

# Apply the mapping function to the AgeGroup column
data['AgeGroup'] = data['AgeGroup'].apply(map_age_group)

# %%
data.head()
# Out:
#    Sex  Year  AgeGroup  Ethnicity  Race  Deaths  Population  Crude Rate  \
# 0    1  1999         4          0     1      19     5764304         0.3
# 1    1  1999         5          0     1      27     6211495         0.4
# 2    1  1999         6          0     1      20     6833145         0.3
# 3    1  1999         7          0     1      30     8063922         0.4
# 4    1  1999         8          0     1      20     8131895         0.2
#
#    Survival Rate scaled  Survival Rate
# 0              0.968219       0.999997
# 1              0.942440       0.999996
# 2              0.977274       0.999997
# 3              0.957810       0.999996
# 4              0.988743       0.999998

# %%
# Define features and target variables
features = ['Sex', 'Year', 'AgeGroup', 'Ethnicity', 'Race']
target = 'Crude Rate'

# %%
data.head()
# Out:
#    Sex  Year  AgeGroup  Ethnicity  Race  Deaths  Population  Crude Rate  \
# 0    1  1999         4          0     1      19     5764304         0.3
# 1    1  1999         5          0     1      27     6211495         0.4
# 2    1  1999         6          0     1      20     6833145         0.3
# 3    1  1999         7          0     1      30     8063922         0.4
# 4    1  1999         8          0     1      20     8131895         0.2
#
#    Survival Rate scaled  Survival Rate
# 0              0.968219       0.999997
# 1              0.942440       0.999996
# 2              0.977274       0.999997
# 3              0.957810       0.999996
# 4              0.988743       0.999998

# %%
# Normalize the features and target
scaler_features = MinMaxScaler()
scaler_target = MinMaxScaler()


data[features] = scaler_features.fit_transform(data[features])
joblib.dump(scaler_features, 'HLscalerX.joblib')
data[[target]] = scaler_target.fit_transform(data[[target]])
joblib.dump(scaler_target, 'HLscalerY.joblib')
# Out:
# ['HLscalerY.joblib']

# %%
# Access the 'Survival Rate' column
survival_rate_column = data['Survival Rate'].values

# Reshape the data to fit the scaler's requirements (if it's a single feature)
survival_rate_column = survival_rate_column.reshape(-1, 1)

# Initialize the MinMaxScaler
scaler_survivalrate = MinMaxScaler()

# Fit and transform the data
ss_rate_scaled = scaler_survivalrate.fit_transform(survival_rate_column)
joblib.dump(scaler_survivalrate, 'HLscalerT.joblib')
# Out:
# ['HLscalerT.joblib']

# %%
# Split the data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# %%
# Prepare the data for LSTM
def create_dataset(data, features, target, seq_length=1):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[features].iloc[i:i+seq_length].values)
        y.append(data[target].iloc[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 20
X_train, y_train = create_dataset(train_data, features, target, seq_length)
X_test, y_test = create_dataset(test_data, features, target, seq_length)

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(seq_length, len(features))))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(32))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Save the model
joblib.dump(model, 'HLmodel.joblib')

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 0.0650 - val_loss: 0.0773
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0382 - val_loss: 0.0709
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0444 - val_loss: 0.0702
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0406 - val_loss: 0.0709
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0359 - val_loss: 0.0678
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0396 - val_loss: 0.0687
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0428 - val_loss: 0.0662
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0359 - val_loss: 0.0589
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0312 - val_loss: 0.0492
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0240 - val_loss: 0.0467
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0273 - val_loss: 0.0375
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0276 - val_loss: 0.0377
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0234 - val_loss: 0.0362
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0228 - val_loss: 0.0367
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0235 - val_loss: 0.0357
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0209 - val_loss: 0.0390
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0240 - val_loss: 0.0320
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0211 - val_loss: 0.0327
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0200 - val_loss: 0.0341
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0225 - val_loss: 0.0333
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0214 - val_loss: 0.0289
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0178 - val_loss: 0.0261
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0219 - val_loss: 0.0307
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0185 - val_loss: 0.0256
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0194 - val_loss: 0.0259
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0158 - val_loss: 0.0220
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0164 - val_loss: 0.0305
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0171 - val_loss: 0.0275
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0197 - val_loss: 0.0262
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0199 - val_loss: 0.0202
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0169 - val_loss: 0.0272
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0197 - val_loss: 0.0204
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0172 - val_loss: 0.0201
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0150 - val_loss: 0.0225
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0145 - val_loss: 0.0179
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0175 - val_loss: 0.0275
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0158 - val_loss: 0.0199
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0154 - val_loss: 0.0167
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0175 - val_loss: 0.0167
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0132 - val_loss: 0.0172
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0181 - val_loss: 0.0279
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0151 - val_loss: 0.0234
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0181 - val_loss: 0.0171
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0146 - val_loss: 0.0153
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0133 - val_loss: 0.0143
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0131 - val_loss: 0.0146
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0119 - val_loss: 0.0190
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0117 - val_loss: 0.0219
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0117 - val_loss: 0.0174
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0113 - val_loss: 0.0219
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
# Inverse transform the predictions and actual values
train_predict = scaler_target.inverse_transform(train_predict)
test_predict = scaler_target.inverse_transform(test_predict)
y_train = scaler_target.inverse_transform(y_train.reshape(-1, 1))
y_test = scaler_target.inverse_transform(y_test.reshape(-1, 1))

# %%
# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(range(len(y_train)), y_train, label='Training Actual')
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, label='Testing Actual')
plt.plot(range(len(y_train)), train_predict, label='Training Predictions')
plt.plot(range(len(y_train), len(y_train) + len(y_test)), test_predict, label='Testing Predictions')
plt.legend()
plt.show()

# %%
# Function to predict future crude rate based on user input
def predict_future_crude_rate(model, user_input, scaler_features, scaler_target, seq_length=3):
    # Normalize user input
    user_input = scaler_features.transform([user_input])
    user_input = np.array([user_input for _ in range(seq_length)]).reshape(1, seq_length, -1)
    
    # Make prediction
    prediction = model.predict(user_input)
    prediction = scaler_target.inverse_transform(prediction)
    
    return prediction[0][0]

# %%
# Example usage: Predict future crude rate for a given user input
user_input = [1, 2008, 1, 0, 1]  # Replace with actual input
predicted_crude_rate = predict_future_crude_rate(model, user_input, scaler_features, scaler_target)
print(f"Predicted Crude Rate: {predicted_crude_rate}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 873ms/step
# Predicted Crude Rate: 0.29960522055625916
